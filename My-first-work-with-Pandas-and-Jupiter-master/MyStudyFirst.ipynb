# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Student_performans = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
StPer = Student_performans
Student_performans
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
Student_performans.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
Student_performans.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
Student_performans.iloc[5:10, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 5  female        group B          associate's degree
# 6  female        group B                some college
# 7    male        group B                some college
# 8    male        group D                 high school
# 9  female        group B                 high school

# %%
Student_performans.iloc[[3, 1, 4], -4:-1]
# Out:
#   test preparation course  math score  reading score
# 3                    none          47             57
# 1               completed          69             90
# 4                    none          76             78

# %%
Spwn = Student_performans.iloc[[3, 1, 4]]
Spwn.index = ['man1', 'women1', 'men2']

# %%
Spwn
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# man1      male        group A          associate's degree  free/reduced
# women1  female        group C                some college      standard
# men2      male        group C                some college      standard
#
#        test preparation course  math score  reading score  writing score
# man1                      none          47             57             44
# women1               completed          69             90             88
# men2                      none          76             78             75

# %%
Spwn.loc[['man1', 'men2'], ['lunch', 'gender']]
# Out:
#              lunch gender
# man1  free/reduced   male
# men2      standard   male

# %%
Student_performans.iloc[:, 1:3]
# Out:
#     race/ethnicity parental level of education
# 0          group B           bachelor's degree
# 1          group C                some college
# 2          group B             master's degree
# 3          group A          associate's degree
# 4          group C                some college
# ..             ...                         ...
# 995        group E             master's degree
# 996        group C                 high school
# 997        group C                 high school
# 998        group D                some college
# 999        group D                some college
#
# [1000 rows x 2 columns]

# %%
Student_performans
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
spwcm = Student_performans['writing score'].mean()

# %%
Student_performans.loc[Student_performans['writing score'] > spwcm]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
query = (Student_performans['writing score'] > spwcm) & (Student_performans.gender == 'female')

# %%
Student_performans.loc[query]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
z = Student_performans.lunch == 'free/reduced'

# %%
Student_performans.loc[z]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
StPer = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
gr1 = StPer.lunch == 'standard'
gr2 = StPer.lunch == 'free/reduced'

# %%
StPer[gr1]
GR1 = StPer[gr1]
GR1.describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
StPer[gr2]
GR2 = StPer[gr2]
GR2.describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
StPer.columns = StPer.columns.str.replace(' ','_')
StPer
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
StPer.query('math_score>74')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 13     male        group A                some college      standard
# 16     male        group C                 high school      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
z = 72

# %%
StPer.query('math_score>@z')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 13     male        group A                some college      standard
# 16     male        group C                 high school      standard
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
jj = [i for i in list(StPer) if 'score' in i]
StPer[jj]
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
StPer.filter(like='score')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-43f4b20d45f9> in <module>
# ----> 1 StPer.filter(like='score')
#
# NameError: name 'StPer' is not defined

# %%
mean_scores = StPer.groupby(['gender', 'race/ethnicity'], as_index = False) \
    .aggregate({'math_score': 'mean', 'writing_score': 'mean'}) \
    .rename(columns = {'math_score': 'mean_math_score', 'writing_score': 'mean_writing_score'})

# %%
mean_scores
# Out:
#    gender race/ethnicity  mean_math_score  mean_writing_score
# 0  female        group A        58.527778           67.861111
# 1  female        group B        61.403846           70.048077
# 2  female        group C        62.033333           71.777778
# 3  female        group D        65.248062           75.023256
# 4  female        group E        70.811594           75.536232
# 5    male        group A        63.735849           59.150943
# 6    male        group B        65.930233           60.220930
# 7    male        group C        67.611511           62.712230
# 8    male        group D        69.413534           65.413534
# 9    male        group E        76.746479           67.394366

# %%
StPer.groupby('gender', as_index = False) \
    .aggregate({'math_score': ['mean', 'count', 'std'], 'writing_score': ['mean', 'min', 'max']})
# Out:
#    gender math_score                  writing_score
#                 mean count        std          mean min  max
# 0  female  63.633205   518  15.491453     72.467181  10  100
# 1    male  68.728216   482  14.356277     63.311203  15  100

# %%
StPer.sort_values(['gender', 'math_score'], ascending = False) \
    .groupby('gender').head()
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
StPer['Total_score'] = StPer.filter(like='score').sum(axis=1)

# %%
StPer = StPer.assign(tsl = np.log(StPer.Total_score))
StPer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dc352262c7b3> in <module>
# ----> 1 StPer = StPer.assign(tsl = np.log(StPer.Total_score))
#       2 StPer
#
# NameError: name 'StPer' is not defined

# %%
StPer.columns = StPer.columns.str.replace(' ','_')
StPer.reading_score.hist();

# %%
StPer.plot.scatter(x='math_score', y='reading_score')

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', data=StPer, fit_reg = False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %%
ax
