# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2 = pd.read_csv('dataset_209770_6.txt', sep=' ')

# %%
df2
# Out:
#               x            y
# 0    100.050089  1483.761302
# 1    900.716752   621.524926
# 2    912.731818   618.850559
# 3   1387.352808  1405.002422
# 4   1005.366465  1210.539424
# ..          ...          ...
# 85   803.230041   897.794971
# 86  1193.460255   795.462492
# 87  1494.532028   691.583719
# 88   705.521726   985.206466
# 89   777.805547   886.990966
#
# [90 rows x 2 columns]

# %%
df2.plot.scatter(x='x', y='y')

# %%
df['income'].plot()

# %%
df.income.plot()

# %%
df.plot(kind='line')

# %%
sns.lineplot(data=df)

# %%
df.plot()

# %%
plt.plot(df.index, df.income)

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
df3 = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv')

# %%
df3
# Out:
#   Unnamed: 0  species0  species1  species2  species3  species4
# 0   species0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1   species1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2   species2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3   species3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4   species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
df3.head()
# Out:
#   Unnamed: 0  species0  species1  species2  species3  species4
# 0   species0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1   species1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2   species2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3   species3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4   species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g=pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv',index_col=0)
g
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(data=g, cmap="viridis");

# %%
ddf = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
ddf
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
ddf['cnt'] = ddf.roles.str.count(',')+1
ddf.cnt.hist()

# %%
ddf.query('cnt==1')
# Out:
#     Unnamed: 0 attack_type  id  legs localized_name                name  \
# 21          21      Ranged  22     2           Zeus  npc_dota_hero_zuus
#
#    primary_attr      roles  cnt
# 21          int  ['Nuker']    1

# %%
fdf = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
fdf
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
for column in fdf:
    sns.kdeplot(fdf[column])
    #sns.distplot(fdf[column], kde_kws={ "label":column})

# %%
sns.violinplot(fdf['petal length'])

# %%
sns.pairplot(fdf, hue="species")

# %%
fdf.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000
